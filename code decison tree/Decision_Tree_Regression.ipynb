# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Position_Salaries.csv")

# %%
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
#1:2 có nghĩa là [1,2)
#,2 có nghĩa lấy giá trị cột 2 thành mãng 2 chiều
# da ta set input 1 thuộc tính thì nên làm thành mãng 2 chiều hết k sẽ bị lỗi
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# ve cay
# đúng rẽ trái , sai rẽ phải
import matplotlib.pyplot as plt
from sklearn import tree
fig =plt.figure(figsize=(15,10))
g=tree.plot_tree(regressor,feature_names =X , filled = True, rounded = True)

# %%
y_pred = regressor.predict([[6.5]])
y_pred
# Out:
# array([150000.])

# %%
y_pred = regressor.predict([[8.7]])
y_pred
# Out:
# array([500000.])
